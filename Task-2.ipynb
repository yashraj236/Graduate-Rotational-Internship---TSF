# %% [markdown]
# # Task - 3¶
#
# # Perform 'Exloratory Data Analysis' on dataset 'SampleSuperstore'
#
# ## As a business manager, try to find out the weak areas where you can work to make more profit.
#
# ## Name - Yashraj Agarwal

# %%
import os #Standard imports 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Import Data

# %%
data = pd.read_csv("C:\\Users\\yashr\\Downloads\\SampleSuperstore.csv")
print("data import successfully")
# Out:
# data import successfully

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data['Ship Mode'].unique
# Out:
# <bound method Series.unique of 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship Mode, Length: 9994, dtype: object>

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.drop_duplicates(keep='first' , inplace=True)

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Before we dive info the details of creating visualization with Matplotlib.¶
# ## Since it is a financial lets have a look at profit and loss statements

# %%
fig,axes=plt.subplots(figsize=(15,7))
sb.distplot(data.Profit)

# %%
data1=data.loc[:,['Profit','Sales']]
data1.head()
# Out:
#      Profit     Sales
# 0   41.9136  261.9600
# 1  219.5820  731.9400
# 2    6.8714   14.6200
# 3 -383.0310  957.5775
# 4    2.5164   22.3680

# %%
data2=data1.sort_values(['Profit'],ascending=False)

# %%
data2.head(10)
# Out:
#          Profit      Sales
# 6826  8399.9760  17499.950
# 8153  6719.9808  13999.960
# 4190  5039.9856  10499.970
# 9039  4946.3700   9892.740
# 4098  4630.4755   9449.950
# 2623  3919.9888  11199.968
# 509   3177.4750   6354.950
# 8488  2799.9840   8749.950
# 7666  2591.9568   5399.910
# 6520  2504.2216   5443.960

# %%
data2['Profit'].head(10).plot(kind='bar')

# %%
data2['Profit'].tail(10).plot(kind='bar')

# %%
corr=data.corr()

# %%
sb.heatmap(corr,annot=True,cmap='Greens')

# %%
data['Postal Code']=data['Postal Code'].astype('object')

# %%
Data=data.drop(['Postal Code'],axis=1)

# %%
sb.pairplot(data,hue='Ship Mode')

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
sb.pairplot(Data,hue='Segment')

# %%
sb.countplot(x='Segment', data=data, palette='rainbow')

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
sb.countplot(x='Category',data=data,palette='rainbow')

# %%
sb.pairplot(data,hue='Category')

# %%
plt.figure(figsize=(12,10))
data['Sub-Category'].value_counts().plot.pie()

# %%
Data['State'].value_counts()
# Out:
# California              1996
# New York                1127
# Texas                    983
# Pennsylvania             586
# Washington               502
# Illinois                 491
# Ohio                     468
# Florida                  383
# Michigan                 254
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   123
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(15,12))
sb.countplot(x='State',data=data,palette='rocket_r',order=data['State'].value_counts().index)

# %%
data.hist(figsize=(10,10),bins=50)
plt.show()

# %%
plt.figure(figsize=(10,8))
data['Region'].value_counts().plot(kind='pie',autopct='%1.2f%%')
plt.show()

# %%
from matplotlib import style

# %%
fig,ax=plt.subplots(figsize=(16,8))
ax.scatter(data['Sales'],data['Profit'])
ax.set_xlabel('Profit')
plt.show()

# %%
sb.lineplot(x='Discount',y='Profit',data=data)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sb.lineplot(x='Quantity',y='Profit',label='Profit',data=data)
plt.show()

# %%
data.groupby('Segment')[['Profit','Sales']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('Profit/loss and Sales')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title('Segment wise sales in each region')
sb.barplot(x='Region',y='Sales',data=data,hue='Segment',order=data['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region')
plt.show()

# %%
data.groupby('Region')[['Profit','Sales']].sum().plot.bar(color=['yellow','blue'],figsize=(8,5))
plt.ylabel('Profit/loss and sales')
plt.show()

# %%
ps=data.groupby('State')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['red','blue'],figsize=(15,8))
plt.title('Profit/loss & Sales across Stress')
plt.xlabel('States')
plt.ylabel('Profitnloss & Sales')
plt.show()

# %%
top_states=data['State'].value_counts()

# %%
top_states.head(10)
# Out:
# California        1996
# New York          1127
# Texas              983
# Pennsylvania       586
# Washington         502
# Illinois           491
# Ohio               468
# Florida            383
# Michigan           254
# North Carolina     249
# Name: State, dtype: int64

# %% [markdown]
# ## Let's see how money is divided in these strip mode categories

# %%
Profitandloss=data['Profit']
plt.plot(Profitandloss)
plt.title("Profit and loss")
# Out:
# Text(0.5, 1.0, 'Profit and loss')

# %%
Profitandloss.max()
# Out:
# 8399.976

# %%
Profitandloss.min()
# Out:
# -6599.978

# %%
sb.boxplot(data['Category'],Profitandloss) #here we can see that Technology has the both the Extreme points w.r.t profit

# %%
ps=data.groupby('Sub-Category')[['Sales','Profit']].sum().sort_values(by='Sales',ascending=False)
ps[:].plot.bar(color=['red','blue'],figsize=(15,8))
plt.title('Profit/loss & Sales across States')
plt.xlabel('Sub-Category')
plt.ylabel('Profitnloss & Sales')
plt.show()

# %% [markdown]
# #  Conclusion :¶
# ## We need to invest more in technology category. Most people see standard ship mode of delivery. All three modes of First class, Second class, standard a major role in our superstore ship mode. Each offers benefits that the other mode of transport. It is up to you to make a well-informed decision of choosing the right mode of shipping that will be beneficial for your business
